# %%
import os
import re
import json
import bisect

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DATA_DIR_RAW = '/Users/chenkx/Desktop/TBIC-not_synced/Negation/data/2010_relations_challenge'
DATA_DIR = r'/Users/chenkx/Box Sync/NLP group/2010 i2b2 challenge - rel'
MAP_DIR1 = "/Users/chenkx/Desktop/TBIC-not_synced/Negation/data/simple_header_map.json"
MAP_DIR2 = "/Users/chenkx/Desktop/TBIC-not_synced/Sectionizer/data/section_mapping/sectionTypeMapping.json"
MAP_DIR = "/Users/chenkx/Desktop/TBIC-not_synced/Negation/notebooks/2010Corpus/section_map_v1.csv"

# %% [markdown]
# ### Combine section map for the train set and the test set

# %%
with open("/Users/chenkx/Desktop/TBIC-not_synced/Negation/notebooks/2010Corpus/section_mapping_v2_train.csv", 'r') as f:
    train_map = f.read()
with open("/Users/chenkx/Desktop/TBIC-not_synced/Negation/notebooks/2010Corpus/Section_mapping_v2_test.csv", 'r') as f:
    test_map = f.read()
train_map = train_map.split('\n')[1:]
train_map = {i.split(',')[0]:i.split(',')[1] for i in train_map}
test_map = test_map.split('\n')[1:]
test_map = {i.split(',')[0]:i.split(',')[1] for i in test_map}

# %%
test_map
# Out:
# {'medications': 'Medications',
#  'discharge date': 'Date/Time',
#  'd': 'Date/Time',
#  't': 'Date/Time',
#  'date': 'Date/Time',
#  'past medical history': 'Past history',
#  'present illness': 'Present illness',
#  'hospital course': 'Hospital course',
#  'diagnoses': 'Diagnoses',
#  'sex': 'Patient information/Demographics',
#  'disposition': 'Follow-up/Instructions',
#  'allergies': 'Allergies',
#  'physical examination': 'Physical examination/Status',
#  'report status': 'Unknown/Unclassified',
#  'service': '?',
#  'date of birth': 'Date/Time',
#  'signed electronically by': 'Providers',
#  'r': 'Unknown/Unclassified',
#  'social history': 'Social history',
#  'dictated by': 'Providers',
#  'patient name': 'Patient information/Demographics',
#  'attending': 'Providers',
#  'labs': 'Laboratory tests',
#  'job id': '?',
#  'attending physician': 'Providers',
#  'dictator': 'Providers',
#  'discharge instructions': 'Follow-up/Instructions',
#  'abdomen': 'Subsection',
#  'cc': 'Chief complaint',
#  'family history': 'Family history',
#  'cardiovascular': 'Subsection',
#  'discharge condition': 'Follow-up/Instructions',
#  'age': 'Patient information/Demographics',
#  'extremities': 'Subsection',
#  'chief complaint': 'Chief complaint',
#  'follow up': 'Follow-up/Instructions',
#  'evaluation date': 'Date/Time',
#  'principal diagnosis': 'Diagnoses',
#  'tr': '?',
#  'dd': '?',
#  'td': '?',
#  'patient': 'Patient information/Demographics',
#  'dob': 'Date/Time',
#  'author': 'Providers',
#  'physical exam': 'Physical examination/Status',
#  'heent': 'Subsection',
#  'start': '?',
#  'neurology': 'Subsection',
#  'completed by': 'Providers',
#  'surgical procedure': 'Procedures/Surgery',
#  'brief hospital course': 'Hospital course',
#  'condition on discharge': 'Follow-up/Instructions',
#  'pertinent results': 'Investigations/Results',
#  'drug form': '?',
#  'gastrointestinal': 'Subsection',
#  'mrn': '?',
#  'lungs': 'Subsection',
#  'name': 'Patient information/Demographics',
#  'dict': 'Providers',
#  'respiratory': 'Subsection',
#  'impression': 'Assessment',
#  'batch': '?',
#  'past history': 'Past history',
#  'associated diagnosis': 'Diagnoses',
#  'general appearance': '?',
#  'neck': 'Subsection',
#  'summary of hospitalization': 'Hospital course',
#  'skin': 'Subsection',
#  'general': '?',
#  'principal procedure': 'Procedures/Surgery',
#  'admitted': '?',
#  'bp': '?',
#  'attend': 'Providers',
#  'diet': 'Nutrition',
#  'musculoskeletal': 'Subsection',
#  'resp': '?',
#  'activity': '?',
#  'pulse': '?',
#  'heart': 'Subsection',
#  'dictating for': 'Providers',
#  'secondary diagnoses': 'Diagnoses',
#  'unit number': '?',
#  'neuro': 'Subsection',
#  'discharged': '?',
#  'discharge status': '?',
#  'refills': 'Medications',
#  'operations and procedures': 'Procedures/Surgery',
#  'chest': 'Subsection',
#  'review of systems': 'Review of systems',
#  'cardiac': 'Subsection',
#  'vitals': '?',
#  'gen': '?',
#  'service of': '?',
#  'date of discharge': 'Date/Time',
#  'followup': 'Follow-up/Instructions',
#  'ext': '?',
#  'other': '?',
#  'reason for admission': 'Reasons/Indications',
#  'date of admission': 'Date/Time',
#  'current medications': 'Medications',
#  'room': 'Patient information/Demographics',
#  'discharge patient on': 'Date/Time',
#  'additional comments': '?',
#  'entered by': 'Providers',
#  'neurologic': 'Subsection',
#  'history': '?',
#  'hospital course and treatment': 'Hospital course',
#  'reason for override': '?',
#  'brief resume of hospital course': 'Hospital course',
#  'cv': '?',
#  'tran': '?',
#  'registration date': 'Date/Time',
#  'admit diagnosis': 'Diagnoses',
#  'provider': 'Providers',
#  'pcp name': 'Providers',
#  'provider number': 'Providers',
#  'temp': '?',
#  'facility': '?',
#  'potentially serious interaction': '?',
#  'special procedures and operations': 'Procedures/Surgery',
#  'infectious disease': '?',
#  'discharge summary name': '?',
#  'assessment/plan': 'Assessment/Plan',
#  'instructions': 'Follow-up/Instructions',
#  'allergy': 'Allergies',
#  'family contacts': '?',
#  'follow-up': 'Follow-up/Instructions',
#  'hematology': 'Subsection',
#  'condition at discharge': 'Follow-up/Instructions',
#  'report': '?',
#  'mri c-spine': '?',
#  'consults': 'Consultations',
#  'sensory': '?',
#  'physical examination on admission': 'Physical examination/Status',
#  'head': 'Subsection',
#  'care recommendations': 'Plan',
#  'motor': '?',
#  'alert overridden': '?',
#  'principal diagnoses': 'Diagnoses',
#  'transfer date': 'Date/Time',
#  'findings': 'Physical examination/Status',
#  'problems and management are as follows': 'Problems',
#  'cardiovascular exam': 'Subsection',
#  'dicatated by': 'Providers',
#  'doctors discharge orders': '?',
#  'other studies': '?',
#  'mr angiogram intracranial vessels': 'Investigations/Results',
#  'last update': '?',
#  'collected': '?',
#  'specimen desc': '?',
#  'culture': '?',
#  'condition': '?',
#  'procedure': 'Procedures/Surgery',
#  'genitourinary': 'Subsection',
#  'primary pediatrician': 'Providers',
#  'adverse drug reactions': '?',
#  'code status': 'Advance directive/Code',
#  'physical examination on presentation': 'Physical examination/Status',
#  'transfer medications': 'Medications',
#  'procedures': 'Procedures/Surgery',
#  'associated procedures': 'Procedures/Surgery',
#  'transferred to': 'Hospital course',
#  'ekg': 'Investigations/Results',
#  'psychosocial': '',
#  'habits': '?',
#  'indications': 'Present illness',
#  'summary of hospital course by systems': 'Hospital course',
#  'name of primary pediatrician': 'Providers',
#  'social services consulted re': 'Consultations',
#  'coordination': '?',
#  'sensitivities': '?',
#  'associated diagnoses': 'Diagnoses',
#  'serious interaction': '?',
#  'patient states complaint': 'Chief complaint',
#  'other procedures': 'Procedures/Surgery',
#  'back': '?',
#  'ros': 'Review of systems',
#  'reflexes': '?',
#  'problems': 'Problems',
#  'rectal': 'Subsection',
#  'prophylaxis': '?',
#  'psh': 'Past history',
#  'hold if': '?',
#  'extrem': 'Subsection',
#  'orientation': '?',
#  'brief history': 'Present illness',
#  'consultants': 'Consultations',
#  'laboratory examination': 'Laboratory tests',
#  'override notice': '?',
#  'treatment rendered': '?',
#  'past obstetrical history': 'Past history',
#  'escription document': '?',
#  'discharge follow-up': 'Follow-up/Instructions',
#  'echo': '?',
#  'conclusions': 'Assessment/Plan',
#  'all': '?',
#  'pulmonary': 'Subsection',
#  'transfer instructions': 'Follow-up/Instructions',
#  'weight': 'Patient information/Demographics',
#  'intake': '?',
#  'pulm': 'Subsection',
#  'studies completed': '?',
#  'pelvic': 'Subsection',
#  'followup appointments': 'Follow-up/Instructions',
#  'surgical history': 'Past history',
#  'clinical infections': '?',
#  'pertinent laboratory data on presentation': 'Laboratory tests',
#  'acc': '?',
#  'net': '?',
#  'tele': 'Unknown/Unclassified',
#  'phone': 'Unknown/Unclassified',
#  'pmi': 'Past history',
#  'current respiratory parameters': '?',
#  'regular rhythm': '?',
#  'subcutaneous heparin': '?',
#  'title': '?',
#  'sensation': '?',
#  'cn': '?',
#  'stop': '?',
#  'care and recommendations': 'Plan',
#  'pcc': '?',
#  'discharge orders': '?',
#  'previous override information': '?',
#  'follow up service': 'Follow-up/Instructions',
#  'imaging': 'Investigations/Results',
#  'immunizations recommended': 'Immunizations',
#  'constitutional': '?',
#  'gi': '?',
#  'cranial nerves': '?',
#  'investigations/results': 'Investigations/Results',
#  'return to work': 'Follow-up/Instructions',
#  'benefits assigned': '?',
#  'history and reason for hospitalization': 'Reasons/Indications',
#  'hpi': 'Present illness',
#  'pmh': 'Past history',
#  'transferred to care of': '?',
#  'discharge activity': 'Follow-up/Instructions',
#  'pertinent consults': 'Consultations',
#  'medications at discharge': 'Medications',
#  'complications': 'Complications',
#  'cxr': 'Radiology',
#  'admitting physician': 'Providers',
#  'pulses': '?',
#  'surgery': 'Procedures/Surgery',
#  'bilateral lower extremities': '?',
#  'hct': 'Investigations/Results',
#  'ck': 'Investigations/Results',
#  'chemistries': '?',
#  'follow-up appointment': 'Follow-up/Instructions',
#  'neuro exam': 'Subsection',
#  'language': '?',
#  'read by': 'Providers',
#  'physical examination on discharge': 'Physical examination/Status',
#  'ct pelvis': 'Radiology',
#  'condition upon discharge': 'Present illness',
#  'follow up care': 'Follow-up/Instructions',
#  'hr': '?',
#  'cad': '?',
#  'medications upon discharge': 'Medications',
#  'admission laboratory data': 'Laboratory tests',
#  'the problems and management are as follows': 'Problems',
#  'follow-up instructions': 'Follow-up/Instructions',
#  'condition at the time of discharge': 'Present illness',
#  'gu': '?',
#  'id': '?',
#  'source': '?',
#  'activities': '?',
#  'pertinent laboratories': 'Laboratory tests',
#  'intake by po': '?',
#  'arterial pulses': '?',
#  'psychiatric': '?',
#  'other problems': 'Problems',
#  'laboratory data on presentation': 'Laboratory tests',
#  '#NAME?': '?',
#  'prescriptions': 'Medications',
#  'radiology studies': 'Radiology',
#  'chest x-ray': 'Radiology',
#  'abdominal pain': 'Subsection',
#  'notation': '?',
#  'cause of death': '?',
#  'rate': '?',
#  'rhythm': '?',
#  'bowel sounds': 'Subsection',
#  'liver': 'Subsection',
#  'nodes': '?',
#  'estimated edc': '?',
#  'breasts': '?',
#  'other diagnoses': 'Diagnoses',
#  'procedures performed': 'Procedures/Surgery',
#  'immunizations': 'Immunizations',
#  'audiology': '?',
#  'reviewed by': '?',
#  'mental status': '?',
#  'gait': '?',
#  'follow - up': 'Follow-up/Instructions',
#  'condition on transfer': '?',
#  'urinalysis': '?',
#  'code': 'Advance directive/Code',
#  'summary of hospital course': '?',
#  'note': '?',
#  'follow-up plans': 'Follow-up/Instructions',
#  'pcp notified by md': 'Providers',
#  'discharge diet': 'Nutrition',
#  'other pertinent secondary diagnoses': 'Diagnoses',
#  'p': 'Assessment/Plan',
#  'principal procedures and tests': 'Procedures/Surgery',
#  'pathology': 'Investigations/Results',
#  'standardized discharge instructions': 'Follow-up/Instructions',
#  'recommendations': 'Plan',
#  'secondary': '?',
#  'principle diagnosis': 'Diagnoses',
#  'discrete results only': 'Investigations/Results',
#  'prenatal screens': '?',
#  'respirations': '?',
#  'transferred': '?',
#  'admission disposition': 'Present illness',
#  'medical management': 'Medications',
#  'cardiac risk factors': '?',
#  'vs': '?',
#  'studies': 'Investigations/Results',
#  'primary admission diagnoses': 'Diagnoses',
#  'significant procedures done for the patient while on admission are as follows': 'Procedures/Surgery',
#  'the findings are as follows': 'Physical examination/Status',
#  'the patient was managed on the following issues during admission and discharge': 'Problems',
#  'the patient is being discharged home on the following medications': 'Medications',
#  'procedures during hospitalization': 'Procedures/Surgery',
#  'transfer disposition': 'Follow-up/Instructions',
#  'pertinent labs': 'Laboratory tests',
#  'digrimme instructions': '?',
#  'pediatrician': 'Providers',
#  'headache': '?',
#  'discharge medicines': 'Medications',
#  'clinical infection': '?',
#  'other medical problems': 'Problems',
#  'laboratory studies on discharge': 'Laboratory tests',
#  'perinatal history': 'Past history',
#  'follow up appointments': 'Follow-up/Instructions',
#  'other workup': '?',
#  'obhx': 'Past history',
#  'products': '?',
#  'causative factors': '?',
#  'the total bypass time': '?',
#  'total crossclamp time': '?',
#  'labs at osh c cr': 'Laboratory tests',
#  'gluc': '?',
#  'mb': '?',
#  'hospital course and outcome': 'Hospital course',
#  'disposition and discharge medications': 'Medications',
#  'neurologic examination': 'Subsection',
#  'in summary': '?',
#  'secondary anesthesia': '?',
#  'neurologically': 'Subsection',
#  'pulmonary wise': 'Subsection',
#  'gi wise': '?',
#  'hematologically': 'Subsection',
#  'drains': '?',
#  'wounds': '?',
#  'she was discharged home with the following medications': 'Medications',
#  'physical therapy': '?',
#  'left upper extremity': 'Subsection',
#  'treatments frequency': '?',
#  'gerardi problem list is as follows': 'Problems',
#  'consulting physicians': 'Consultations',
#  'secondary procedure': 'Procedures/Surgery',
#  'instructions to the patient': '?',
#  'temperature': 'Investigations/Results',
#  'respiratory rate': 'Investigations/Results',
#  'oxygen saturation': 'Investigations/Results',
#  'liver function': 'Subsection',
#  'coagulation': '?',
#  'on transfer': 'Follow-up/Instructions',
#  'serologies': 'Investigations/Results',
#  'feedings at discharge': '?',
#  'car seat position screening': '?',
#  'state newborn screen': '?',
#  'pregnancy history': 'Past history',
#  'physical examination upon admission to the cmed ccu': 'Physical examination/Status',
#  'pertinent labs on discharge': 'Laboratory tests',
#  'discharge planning and instructions': 'Plan',
#  'ct head': 'Radiology',
#  'mri head': 'Radiology',
#  'mra': '?',
#  'carotid ultrasound': '?',
#  'his postoperative course was complicated by': 'Hospital course',
#  'attention': 'Providers',
#  'memory': '?',
#  'east sandwich': '?',
#  'v': '?',
#  'vii': '?',
#  'viii': '?',
#  'ix': '?',
#  'xii': '?',
#  'xi': '?',
#  'motor system': 'Subsection',
#  'sensory system': 'Subsection',
#  'toes': 'Subsection',
#  'multivitamin capsule sig': '',
#  'ocuvite tablet sig': '',
#  'artificial tears drops sig': '',
#  'ensure liquid sig': '',
#  'medications on transfer the stillman infirmary': 'Medications',
#  'transfer condition': 'Follow-up/Instructions',
#  'transfer orders': 'Follow-up/Instructions',
#  'neurological examination': 'Subsection',
#  'kub': '?',
#  'other information': '?',
#  'sensory examination': 'Subsection',
#  'differential': '?',
#  'transcranial dopplers': '?',
#  'holter electrocardiogram': 'Investigations/Results',
#  'electroencephalogram': 'Investigations/Results',
#  'visual field testing': 'Investigations/Results',
#  'problems and management': 'Problems',
#  'disposition plans': 'Plan',
#  'radiographic studies': 'Radiology',
#  'pain control': '?',
#  'transaminitis': '?',
#  'anemia': '?',
#  'hypothyroidism': '?',
#  'current discharge medications': 'Medications',
#  'the patient will be discharged on the following medications': 'Medications',
#  'indications for procedure': 'Present illness',
#  'ct chest': 'Radiology',
#  'ct abdomen': 'Radiology',
#  'bone windows': '?',
#  'neurological exam': 'Subsection',
#  'laboratory on admission': 'Laboratory tests',
#  'condition of discharge': 'Present illness',
#  'laboratory values': 'Laboratory tests',
#  'transfer diagnosis': 'Diagnoses',
#  'discharge summary addendum': '?',
#  'ther procedures': 'Procedures/Surgery',
#  'summary of laboratory and radiological examinations': 'Investigations/Results',
#  'cardiopulmonary resuscitation note': '?',
#  'principal procedures': 'Procedures/Surgery',
#  'in monica': '?',
#  'call the ir clinic on monday to confirm your appointment': '',
#  'mg po daily hold if': '',
#  'cm pe': '?',
#  'access site': '?',
#  'brief hospice course': 'Hospital course',
#  'leuprolide admit diagnosis': 'Diagnoses',
#  'full code additional comments': '?',
#  'admit date': 'Date/Time',
#  'operative date': 'Date/Time',
#  'the following were consulted for ways of increasing ambulation and activity': 'Consultations',
#  'discharge heart rhythm': '?',
#  'laboratory work to be obtained once weekly for two weeks': '',
#  'time spent with patient on day of discharge': '?',
#  'hematologic and infectious disease': '?',
#  'please contact lab control at mattapan community health center for results': '',
#  'immunizations received': 'Immunizations',
#  'coronary disease': '?',
#  'acute kidney injury': '?',
#  'discharge allergies': 'Allergies',
#  'abdominal examination': 'Subsection',
#  'rectal examination': 'Subsection',
#  'skin examination': 'Subsection',
#  'cardiac catheterization': '?',
#  'cmed course': '?',
#  'on transfer to floor team from cmed active issues and plan included': '?',
#  'fever': '?',
#  'bronchial washings': '?',
#  'echocardiogram': 'Investigations/Results',
#  'cardiogram': 'Investigations/Results',
#  'physicians that took care of this patient while at the ph university of medical center are as follows': 'Providers',
#  'consulting plastic surgeon': 'Consultations',
#  'consulting cardiologist': 'Consultations',
#  'consulting cardiac surgeon': 'Consultations',
#  'infectious disease consultant': 'Consultations',
#  'psychiatry': '?',
#  'pain service': '?',
#  'he was subsequently discharged the following day on': '?',
#  'ct cspine': 'Radiology',
#  'postoperative course by systems is as follows': 'Hospital course',
#  'post discharge testing': '?',
#  'post discharge services': '?',
#  'dermatology': '?',
#  'pertinent consultations': 'Consultations',
#  'other meds': 'Medications',
#  'the problems and their management are as follows': 'Problems',
#  'diagnosis on discharge': 'Diagnoses',
#  'key issues': 'Present illness',
#  'right groin': '?',
#  'hemodynamics results body surface area': 'Investigations/Results',
#  'hemoglobin': 'Investigations/Results',
#  'other hemodynamic data': 'Investigations/Results',
#  'primary pediatric care': '?',
#  'her pulmonary': 'Subsection',
#  'dishcarge recommendations': 'Plan',
#  'followup care': 'Follow-up/Instructions',
#  'elevated lactate': '?',
#  'employment': '?',
#  'diverticular disease of the colon': '?',
#  'thorax': '?',
#  'heme': '?',
#  'procedures done during hospitalization': 'Procedures/Surgery',
#  'primary reason for admission': 'Present illness',
#  'discharge diagnoses - as above plus': 'Diagnoses',
#  'lm': '?',
#  'lad': '?',
#  'circ': '?',
#  'rca': '?',
#  'ef': '?',
#  'chronic gi bleeding': '?',
#  'gi bleed study - impression': '?',
#  'egd - impression': '?',
#  'kim phone': '',
#  'gastric biopsy': '?',
#  'where': '?',
#  'chest radiograph': 'Radiology',
#  'at - home medications': 'Medications',
#  'status at discharge': 'Present illness',
#  'heart exam': 'Subsection',
#  'neurologic exam': 'Subsection',
#  'cranial nerve exam': 'Subsection',
#  'viith cranial nerve': '?',
#  'motor exam': 'Subsection',
#  'cerebellar exam': 'Subsection',
#  'drugs': '?',
#  'physical examination on transfer': 'Physical examination/Status',
#  'principle procedure': 'Procedures/Surgery',
#  'pertinent laboratory values on presentation': 'Laboratory tests',
#  'in the deborah vs on arrival were t': '?',
#  'irene field screening where': '?',
#  'presenting history': 'Past history',
#  'chronic back pain': '?',
#  'breast': 'Subsection',
#  'ext gen': '?',
#  'support': '?',
#  'vagina': 'Subsection',
#  'cervix': 'Subsection',
#  'uterus': 'Subsection',
#  'examination': 'Physical examination/Status',
#  'social': 'Social history',
#  'newborn screen': '?',
#  'car seat': '?',
#  'ethanol': '?',
#  'admitting physicians': 'Providers',
#  'referring physician': 'Providers',
#  'his grafts include the following': '?',
#  'gerd operations and procedures': 'Procedures/Surgery',
#  'medications on admit': 'Medications',
#  'genitalia': '?',
#  'mg po bid diet': '',
#  'the patient had a repeat transthoracic echocardiogram prior to drain removal which revealed the following': 'Investigations/Results',
#  'renal': 'Subsection',
#  'additional instructions': 'Follow-up/Instructions',
#  'additional information': '?',
#  'discharge physical examination': 'Physical examination/Status',
#  'nonebrief resume of hospital course': 'Hospital course',
#  'history of present complaint': 'Past history',
#  'the patient had the following radiological studies': 'Radiology',
#  'integument': '?',
#  'critical value called by': '?',
#  'endocrine': '?',
#  'titles': '?',
#  'changes to discharge medications': 'Medications',
#  'cardiac examination': 'Subsection',
#  'access': '?',
#  'cultures': '?',
#  'blood': '?',
#  'card': '?',
#  'infectious disease provider': 'Providers',
#  'provisional diagnosis': 'Diagnoses',
#  'operations and nonsurgical procedures': 'Procedures/Surgery',
#  'general instructions': 'Plan',
#  'cat scan phone': '?',
#  'therapy': '?',
#  'progress': '?',
#  'source of primary pediatric care': '?',
#  'consulting physician': 'Consultations',
#  'ct showed': 'Radiology',
#  'pelvis': 'Subsection',
#  'correction about one of discharge diagnoses': 'Diagnoses',
#  'resp failure': '?',
#  'cirrhosis': '?',
#  'ams': '?',
#  'meds on transfer': 'Medications',
#  'summary of stay': '?',
#  'disposition on discharge': 'Plan',
#  'cpt': '?',
#  'eyes': 'Subsection',
#  'laboratory studies': 'Laboratory tests',
#  'tab po daily diet': '',
#  'past gynecological history': 'Past history',
#  'renal us - impression': 'Assessment',
#  'history of present illness and reason for hospitalization': 'Reasons/Indications',
#  'treatments': '?',
#  'd and c showed grade ii-iii adenocarcinoma with squamous differentiation at wellla uxinny': '?',
#  'refill': '?',
#  'labwork every monday and thursday per transplant clinic': 'Laboratory tests',
#  'tom course': '?',
#  'tc': '?',
#  'rr': '?',
#  'medications on transfer from nursing home': 'Medications',
#  'laboratories at outside hospital': 'Laboratory tests',
#  'summary of hospital course by issues-system': 'Hospital course',
#  'screens': '?',
#  'date of operation': 'Date/Time',
#  'history and reason for admission': 'Present illness',
#  'abdominal computerized tomography scan': 'Investigations/Results',
#  'doctors discharge instructions': 'Plan',
#  'genl': '?',
#  'ms': '?',
#  'recent exam': 'Physical examination/Status',
#  'csf': 'Investigations/Results',
#  'csf cytology': 'Investigations/Results',
#  'ct head findings': 'Radiology',
#  'mri': 'Investigations/Results',
#  'eeg': 'Investigations/Results',
#  'hyperventilation': '?',
#  'intermittent photic stimulation': '?',
#  'sleep': '?',
#  'cardiac monitor': 'Investigations/Results',
#  'pending tests': '?',
#  'commun': '?',
#  'follow up with': '?',
#  'physical examination upon admission to the neonatal intensive care unit': 'Physical examination/Status',
#  'additional laboratory': 'Laboratory tests',
#  'preoperative medications': 'Medications',
#  'the problems of my management are as follows': 'Problems',
#  'prenatal edward': '?',
#  'fluids and electrolytes': '?',
#  'data': '?',
#  'principal procedures done': 'Procedures/Surgery',
#  'left': '?',
#  'in the amanda': '?',
#  'comments': '?',
#  'ca': '?',
#  'other blood chemistry': '?',
#  'n': '?',
#  'k': '?',
#  'cmed ccu': '?',
#  'respiratory status': '?',
#  'cardiovascular status': '?',
#  'recommendations after discharge': 'Plan',
#  'issues': '?',
#  'lymphatics': '?',
#  'recommended follow-up': 'Follow-up/Instructions',
#  'surgical intervention': 'Procedures/Surgery',
#  'complications during admission': 'Present illness',
#  'postoperative diagnosis': 'Diagnoses',
#  'exam on arrival in the lo hospital emergency room': 'Physical examination/Status',
#  'other notalbe labs': 'Laboratory tests',
#  'he was subsequently seen by the gi team who performed an upper endoscopy which demonstrated the following': 'Investigations/Results',
#  'b': '?',
#  'c': '?',
#  'problems and the management are as follows': 'Problems',
#  'identifying data': '?',
#  'her risk factors': '?',
#  'howeaver course': '?',
#  'foanterp': '?',
#  'ct scan': 'Radiology',
#  'most recent results': '?',
#  'phoen': '?',
#  'upright ap view of the chest': '?',
#  'fohintonp': '?',
#  'height': '?',
#  'status': '?',
#  'test': '?',
#  'doppler': '?',
#  'contrast': '?',
#  'tape number': '?',
#  'test location': '?',
#  'technical quality': '?',
#  'referring doctor': '?',
#  'measurements': '?',
#  'right atrium - four chamber length': '?',
#  'left ventricle - septal wall thickness': 'Subsection',
#  'left ventricle - inferolateral thickness': 'Subsection',
#  'left ventricle - diastolic dimension': 'Subsection',
#  'left ventricle - ejection fraction': 'Subsection',
#  'aortic valve - peak velocity': '?',
#  'mitral valve - e wave': '?',
#  'mitral valve - a wave': '?',
#  'interpretation': '?',
#  'left atrium': 'Subsection',
#  'left ventricle': 'Subsection',
#  'right ventricle': 'Subsection',
#  'aorta': '?',
#  'aortic valve': '?',
#  'mitral valve': '?',
#  'tricuspid valve': '?',
#  'pericardium': '?',
#  'general comments': '?',
#  'oak bluffs physician': '?',
#  'pleural effusion': '?',
#  'chf': '?',
#  'diarrhea': '?',
#  'copd': '?',
#  'paf': '?',
#  'rash': '?',
#  'he remains in the intensive care unit and suffers from the following problems': 'Problems',
#  'mental state': '?',
#  'throat': '?',
#  'neur': '?',
#  'blood cultures': '?',
#  'labs on discharge': 'Laboratory tests',
#  'outpatient medications': 'Medications',
#  'history of present illness and hospital course': 'Present illness',
#  'she is being discharged on the following medications': 'Medications',
#  'investigations performed': 'Investigations/Results',
#  'carotids': '?',
#  'the patient arrived on the floor with medications as follows': 'Medications',
#  'principle procedures this admission': 'Procedures/Surgery',
#  'gram stain': '?',
#  'ambulation': '?',
#  'bilateral': '?',
#  'contour': '?',
#  'penis': '?',
#  'mood and affect': '?',
#  'behavior': '?',
#  'judgement': '?',
#  'identification': '?',
#  'transfer diagnoses': 'Diagnoses',
#  'home medications': 'Medications',
#  'course in hospital': '?',
#  'precordium': '?',
#  'heart sounds': 'Subsection',
#  'murmurs': '?',
#  'past gyn history': 'Past history',
#  'impression and plan': 'Assessment/Plan',
#  'blood pressure': '?',
#  'thyroid': '?',
#  'ecg': 'Investigations/Results',
#  'eye': 'Subsection',
#  'red eye': '?',
#  'cbc': '?',
#  'assessment and plan': 'Assessment/Plan',
#  'primary discharge diagnoses': 'Diagnoses',
#  'secondary discharge diagnoses': 'Diagnoses',
#  'radiologic studies': 'Radiology',
#  'date of death': 'Date/Time',
#  'home care': '?',
#  'ophthalmology': '?',
#  'consults obtained': 'Consultations',
#  'hypertension': 'Subsection',
#  'consult': 'Consultations',
#  'significant problems': 'Problems',
#  'operation': '?',
#  'technique': '?',
#  'alcohol': 'Social history',
#  'extr': '?',
#  'ddx': 'Diagnoses',
#  'list of discharge medications': 'Medications',
#  'microbiology': 'Investigations/Results',
#  'oropharynx': '?',
#  'adnexa': '?',
#  'cmed': '?',
#  'post-bypass': '?',
#  'principal discharge diagnosis': 'Diagnoses',
#  'principal procedure or operation': 'Procedures/Surgery',
#  'associated procedures or operations': 'Procedures/Surgery',
#  'postpartum therapeutic procedures': 'Procedures/Surgery',
#  'postpartum disposition': 'Follow-up/Instructions',
#  'postpartum care site': '?',
#  'breast feeding at discharge': '?',
#  'postpartum rh immune globulin': 'Investigations/Results',
#  'electronically signed': 'Providers',
#  'tobacco': 'Social history',
#  'etoh': '?',
#  'brief clinical history': 'Past history',
#  'postoperative course': '?',
#  'renal failure': '?',
#  'cesarean status': '?',
#  'urgency': '?',
#  'uterine incision type': '?',
#  'placenta': '?',
#  'maternal transfer': '?',
#  'initial newborn exam': 'Physical examination/Status',
#  'medications prior to admission': 'Medications',
#  'discharge regimen': '?',
#  'surgical procedures': 'Procedures/Surgery',
#  'brief history of present illness': 'Present illness',
#  'cor': '?',
#  'summary': '?',
#  'special instructions': 'Follow-up/Instructions',
#  'care and recommendations at the time of discharge': '?',
#  'monitor': '?',
#  'reason': 'Reasons/Indications',
#  'underlying medical condition': '?',
#  'reason for this examination': 'Reasons/Indications',
#  'comparisons': '?',
#  'cmed csru': '?',
#  'pump': 'Subsection',
#  'transferred date': '?',
#  'a': 'Assessment/Plan',
#  'heent exam': 'Subsection',
#  'problem list': 'Problems',
#  'edc': '?',
#  'objective': '?',
#  'consultants during this admission': 'Consultations',
#  'nutrition': 'Nutrition',
#  'past gynecologic history': 'Past history',
#  'labs on admission': 'Laboratory tests',
#  'estimated disability and probable duration': '?',
#  'cvs': '?',
#  'appearance': '?',
#  'hydration': '?',
#  'nutritional status': 'Nutrition',
#  'surface': '?'}

# %% [markdown]
# --------

# %%
with open(MAP_DIR, 'r') as f:
    section_map = f.read()
section_map = section_map.split('\n')[1:]
section_map = {i.split(',')[0]:i.split(',')[1] for i in section_map}

# %%
with open(MAP_DIR1, 'r') as f:
    section_map1 = json.load(f)
with open(MAP_DIR2, 'r') as f:
    section_map2_tmp = json.load(f)
section_map2 = {}
# reformat section_map2 to lower case
for i in section_map2_tmp:
    section_map2[i.lower()] = section_map2_tmp[i].lower()
del section_map2_tmp

# %%
filenames = [i[:-4] for i in os.listdir(os.path.join(\
    DATA_DIR, "test", "txt")) \
     if i.endswith(".txt")]

# %%
file = filenames[0]

# %%
with open(os.path.join(DATA_DIR, 'test', 'ref', file+'.ann'), 'r') as f:
    ann = f.readlines()

# %%
def std_header(phrase):
    """
    standardize heading from regex matches.
    First, use simple rules to check if a phrase is a header. Rules:
        1. A header does not contain digits.
    Then, normalize headings by:
        1. converting to lower case
        2. trim white space.
    """    
    if re.search('(^mg )|(^ml )|(^g )', phrase):
        return None
    
    phrase = re.sub(" :$", "", phrase.strip().lower())
    if phrase in section_map1:
        phrase = section_map1[phrase]
    if phrase in section_map2:
        phrase = section_map2[phrase]
    
    if phrase == '':
        return None
    
    return phrase

# %%
class Reader:
    def __init__(self, path, fname):
        """
        :param path - Path to the folder of which subfolders include "txt" and "ref"
        """

        self._path = path
        self.fname = fname
        
        self.ann = {}
        self._ann_raw = []
        self.all_headings = []
        
        with open(os.path.join(self._path, "txt", self.fname+".txt"), 'r') as f:
            self.txt = f.read()
        
    def get_all_headings(self):
        matches = re.finditer('(\n[a-zA-Z -]+)(( :\n)|( : ))', reader.txt)
        for m in matches:
            match = std_header(m.group(0))
            if match:
                b, e = m.span()
                self.all_headings.append( (match, b, e) )
#         self.all_headings = [std_header(match) for i, match in enumerate([re.search('[a-zA-Z ]+(( :$)|( : ))', txt) for txt in self.txt.split('\n')])]
    
    def get_annotation(self):
        """
        {
            fname: {
                iterm_id: {
                    b: int begin_offset, 
                    e: int end_offset, 
                    t: str "type",
                    a: str "assertion", 
                    c: str "concept_raw_text", 
                    s: str "section"
                }
                length: int length of the note 
            }
        }

        """
        fname = self.fname
        with open(os.path.join(self._path, "ref", fname+".ann"), 'r') as f:
            ann_raw = f.read().split('\n')
            self._ann_raw = ann_raw
        
        annotations = {}
        for line in ann_raw:
            line = line.split('\t')
            if line[0].startswith('T'):
                annotations[line[0]] = {
                    'b': int(line[1].split()[1]),  
                    'e': int(line[1].split()[2]), 
                    't': line[1].split()[0], 
                    'a': None, 
                    'c': line[2], 
                    's': None
                }
        for line in ann_raw:
            line = line.split('\t')
            if line[0].startswith('A'):
                if line[1].split()[1] not in annotations:
                    print(f"Warning: {line[0]} ??")
                annotations[line[1].split()[1]]['a'] = line[1].split()[0]
                
        # remove annotations that don't have assertion informaiton 
        delete = []
        for i in annotations:
            if annotations[i]['a'] is None:
                delete.append(i)
        for i in delete:
            del annotations[i]
        
        annotations['length'] = len(self.txt)
        
        self.ann = {fname: annotations}

# %%
all_headings = []
for file in filenames:
    reader = Reader(os.path.join(DATA_DIR, "test"), file)
    reader.get_all_headings()
    all_headings.extend([i[0] for i in reader.all_headings])

# %%
len(all_headings)
# Out:
# 8709

# %%
len(set(all_headings))
# Out:
# 806

# %%
with open('../../ClinicalSectionsOntology-v2.csv', 'r') as f:
    ont = f.read().split('\n')

# %%
ont_map = {}
for line in ont[2:]:
    keys = line.split(',')[5:]
    val = line.split(',')[0]
    key2 = line.split(',')[1]
    abbr = line.split(',')[2]
    ont_map[val.lower()] = val
    for k in keys:
        k = re.sub('"', '', k).strip()
        if k != '':
            ont_map[k.lower()] = val
    if key2 != '':
        ont_map[key2.lower()] = val
    if abbr != '':
        ont_map[abbr.lower()] = val

# %%
# conbine the ontology with the map I created for the train set
ont_map = {**ont_map, **section_map}

# %%
# count un/mapped headings
freq = {}
mapped = {}
for i in all_headings:
    if i in ont_map:
        if i not in mapped:
            mapped[i] = 0
        mapped[i] += 1
        continue
    if i not in freq:
        freq[i] = 0
    freq[i] +=1 
    
freq = [(i, "?", freq[i]) for i in freq]
mapped = [(i, ont_map[i], mapped[i]) for i in mapped]
# freq = sorted(list(freq.items()), key=lambda x:-x[1])
# mapped = sorted(list(mapped.items()), key=lambda x:-x[1])

# %%
to_write = [','.join([i[0], i[1], str(i[2])]) for i in sorted(freq+mapped, key=lambda x:-x[2])]

# %%
to_write[:5]
# Out:
# ['medications,Medications,344',
#  'discharge date,Date/Time,263',
#  'd,Date/Time,262',
#  't,Date/Time,262',
#  'date,Date/Time,234']

# %%
with open('all_headings_2010-test.csv', 'w') as f:
    f.writelines([ i + "\n" for i in to_write])

# %%
[i for i in set(all_headings) if i not in ont_map]
# for some of them manually map. 
# her discharge medications are as followsh, is a heading 
# sort by freq
# Out:
# ['motor system',
#  'treatments frequency',
#  'past gynecological history',
#  'please contact lab control at mattapan community health center for results',
#  'sensory system',
#  'acc',
#  'neuro exam',
#  'the patient had a repeat transthoracic echocardiogram prior to drain removal which revealed the following',
#  'ambulation',
#  'operations and nonsurgical procedures',
#  'investigations performed',
#  'ct head',
#  'motor',
#  'mra',
#  'state newborn screen',
#  'coronary disease',
#  'psychiatric',
#  'data',
#  'bilateral lower extremities',
#  'kub',
#  'fluids and electrolytes',
#  'mitral valve - a wave',
#  'post discharge testing',
#  'disposition and discharge medications',
#  'feedings at discharge',
#  'radiology studies',
#  'procedures done during hospitalization',
#  'last update',
#  'coagulation',
#  'renal us - impression',
#  'phoen',
#  'contour',
#  'sensitivities',
#  'discharge diagnoses - as above plus',
#  'heme',
#  'summary of stay',
#  'other problems',
#  'physical examination upon admission to the cmed ccu',
#  'thorax',
#  'she is being discharged on the following medications',
#  'differential',
#  'general comments',
#  'pulmonary wise',
#  'measurements',
#  'significant procedures done for the patient while on admission are as follows',
#  'follow-up appointment',
#  'pain service',
#  'tape number',
#  'test location',
#  'cirrhosis',
#  'comments',
#  'other studies',
#  'he was subsequently seen by the gi team who performed an upper endoscopy which demonstrated the following',
#  'chest x-ray',
#  'gluc',
#  'doppler',
#  'critical value called by',
#  'rr',
#  'social',
#  'ct cspine',
#  'other hemodynamic data',
#  'chronic gi bleeding',
#  'left',
#  'in the amanda',
#  'multivitamin capsule sig',
#  'transfer diagnosis',
#  'activities',
#  'cardiac monitor',
#  'prophylaxis',
#  'oxygen saturation',
#  'vii',
#  'mg po daily hold if',
#  'gi bleed study - impression',
#  'call the ir clinic on monday to confirm your appointment',
#  'phone',
#  'physical examination upon admission to the neonatal intensive care unit',
#  'principal procedures done',
#  'in monica',
#  'problems and the management are as follows',
#  'pertinent labs',
#  'interpretation',
#  'condition of discharge',
#  'meds on transfer',
#  'mri head',
#  'foanterp',
#  'id',
#  'cn',
#  'pertinent laboratory values on presentation',
#  'b',
#  'her pulmonary',
#  'summary of hospital course by issues-system',
#  'bone windows',
#  'sensory examination',
#  'mr angiogram intracranial vessels',
#  'right atrium - four chamber length',
#  'pertinent labs on discharge',
#  'laboratory studies on discharge',
#  'consulting physicians',
#  'cerebellar exam',
#  'pertinent laboratory data on presentation',
#  'the patient will be discharged on the following medications',
#  'gram stain',
#  'nonebrief resume of hospital course',
#  'history and reason for admission',
#  'right ventricle',
#  'laboratories at outside hospital',
#  'causative factors',
#  'cm pe',
#  'cultures',
#  'key issues',
#  'card',
#  'pmi',
#  'subcutaneous heparin',
#  'the patient had the following radiological studies',
#  'mri c-spine',
#  'medications on transfer from nursing home',
#  'c',
#  'paf',
#  'ix',
#  'viith cranial nerve',
#  'car seat position screening',
#  'laboratory studies',
#  'physical therapy',
#  'follow up with',
#  'follow-up instructions',
#  'pain control',
#  'laboratory data on presentation',
#  'admission laboratory data',
#  'rectal examination',
#  'gi wise',
#  'admit date',
#  'the problems of my management are as follows',
#  'studies completed',
#  'her risk factors',
#  'cpt',
#  'ct chest',
#  'surgical history',
#  'mri',
#  'principle procedures this admission',
#  'pregnancy history',
#  'medications on admit',
#  'abdominal computerized tomography scan',
#  'preoperative medications',
#  'language',
#  'd and c showed grade ii-iii adenocarcinoma with squamous differentiation at wellla uxinny',
#  'csf',
#  'liver function',
#  'psh',
#  'access site',
#  'diagnosis on discharge',
#  'in the deborah vs on arrival were t',
#  'regular rhythm',
#  'therapy',
#  'additional instructions',
#  'egd - impression',
#  'laboratory on admission',
#  'additional information',
#  'genl',
#  'tom course',
#  'the problems and their management are as follows',
#  'ams',
#  'rash',
#  'copd',
#  'pediatrician',
#  'pelvis',
#  'electroencephalogram',
#  'bronchial washings',
#  'headache',
#  'on transfer to floor team from cmed active issues and plan included',
#  'hold if',
#  'other meds',
#  'circ',
#  'ck',
#  '- cxr',
#  'he remains in the intensive care unit and suffers from the following problems',
#  'primary admission diagnoses',
#  'temperature',
#  'discharge medicines',
#  'left ventricle',
#  'source of primary pediatric care',
#  'ct showed',
#  'digrimme instructions',
#  'name of primary pediatrician',
#  'instructions to the patient',
#  'dishcarge recommendations',
#  'tele',
#  'east sandwich',
#  'intermittent photic stimulation',
#  'issues',
#  'followup care',
#  'referring doctor',
#  'indications for procedure',
#  'consulting plastic surgeon',
#  'fever',
#  'labs on discharge',
#  'postoperative course by systems is as follows',
#  'height',
#  'extrem',
#  'neurologic examination',
#  'physical examination on discharge',
#  'the patient is being discharged home on the following medications',
#  'serologies',
#  'prenatal edward',
#  'secondary anesthesia',
#  'hct',
#  'status at discharge',
#  'screens',
#  'the findings are as follows',
#  'operative date',
#  'complications during admission',
#  'follow up care',
#  'hemoglobin',
#  'secondary procedure',
#  'blood',
#  'technical quality',
#  'discharge physical examination',
#  'followup appointments',
#  'transaminitis',
#  'neurologic exam',
#  'refill',
#  'clinical infections',
#  'arterial pulses',
#  'other information',
#  'obhx',
#  'surgical intervention',
#  'recent exam',
#  'motor exam',
#  'left ventricle - inferolateral thickness',
#  'anemia',
#  'ms',
#  'gu',
#  'presenting history',
#  'uterus',
#  'viii',
#  'carotids',
#  'other blood chemistry',
#  'k',
#  'left upper extremity',
#  'status',
#  'skin examination',
#  'intake by po',
#  'additional laboratory',
#  'mitral valve',
#  'pelvic',
#  'other notalbe labs',
#  'hematologically',
#  'penis',
#  'pleural effusion',
#  'tricuspid valve',
#  'ext gen',
#  'support',
#  'she was discharged home with the following medications',
#  'newborn screen',
#  'howeaver course',
#  'lad',
#  'post discharge services',
#  'endocrine',
#  'care recommendations',
#  'cervix',
#  'pericardium',
#  'left ventricle - ejection fraction',
#  'hospital course and outcome',
#  'the problems and management are as follows',
#  'family contacts',
#  'laboratory values',
#  'the patient arrived on the floor with medications as follows',
#  'holter electrocardiogram',
#  'identifying data',
#  'xii',
#  'referring physician',
#  'admitting physicians',
#  'consulting physician',
#  'current discharge medications',
#  'throat',
#  'orientation',
#  'elevated lactate',
#  '- mra kidney',
#  'renal',
#  'clinical infection',
#  'discharge planning and instructions',
#  'cardiovascular status',
#  'outpatient medications',
#  'cmed course',
#  'toes',
#  'ther procedures',
#  'drugs',
#  'cmed ccu',
#  'he was subsequently discharged the following day on',
#  'titles',
#  'procedures during hospitalization',
#  'physicians that took care of this patient while at the ph university of medical center are as follows',
#  'cad',
#  'aortic valve',
#  'his grafts include the following',
#  'car seat',
#  'diverticular disease of the colon',
#  'condition upon discharge',
#  'bilateral',
#  'exam on arrival in the lo hospital emergency room',
#  'access',
#  'cardiopulmonary resuscitation note',
#  'most recent results',
#  'left ventricle - septal wall thickness',
#  'full code additional comments',
#  'follow up appointments',
#  'neurological examination',
#  'dermatology',
#  'transcranial dopplers',
#  'cardiac catheterization',
#  'history of present illness and reason for hospitalization',
#  'neurologically',
#  'correction about one of discharge diagnoses',
#  'disposition on discharge',
#  'ef',
#  'labwork every monday and thursday per transplant clinic',
#  'radiographic studies',
#  'ensure liquid sig',
#  'behavior',
#  'artificial tears drops sig',
#  'eyes',
#  'hemodynamics results body surface area',
#  'abdominal examination',
#  'ethanol',
#  'breast',
#  'gerd operations and procedures',
#  'oak bluffs physician',
#  'brief hospice course',
#  'infectious disease consultant',
#  'coordination',
#  'recommendations after discharge',
#  'on transfer',
#  'diarrhea',
#  'doctors discharge orders',
#  'doctors discharge instructions',
#  'right groin',
#  'neur',
#  'ct head findings',
#  'neurological exam',
#  'culture',
#  'test',
#  'title',
#  'echocardiogram',
#  'pending tests',
#  'consulting cardiologist',
#  'immunizations received',
#  'eeg',
#  'social services consulted re',
#  'ca',
#  'sleep',
#  'wounds',
#  'chf',
#  'other medical problems',
#  'cat scan phone',
#  'gerardi problem list is as follows',
#  'chest radiograph',
#  'date of operation',
#  'carotid ultrasound',
#  'resp failure',
#  'principle procedure',
#  'summary of laboratory and radiological examinations',
#  'the following were consulted for ways of increasing ambulation and activity',
#  'in summary',
#  'fohintonp',
#  'employment',
#  'discharge allergies',
#  'acute kidney injury',
#  'sensation',
#  'judgement',
#  'provisional diagnosis',
#  'examination',
#  'current respiratory parameters',
#  'stop',
#  'the patient was managed on the following issues during admission and discharge',
#  'transfer disposition',
#  'hr',
#  'primary pediatric care',
#  'tab po daily diet',
#  'primary reason for admission',
#  'psychiatry',
#  'heart exam',
#  'problems and management',
#  'mood and affect',
#  'hematologic and infectious disease',
#  'ct scan',
#  'disposition plans',
#  'prescriptions',
#  'physical examination on transfer',
#  'aorta',
#  'laboratory work to be obtained once weekly for two weeks',
#  'recommended follow-up',
#  'mg po bid diet',
#  'total crossclamp time',
#  'left atrium',
#  'ct abdomen',
#  'his postoperative course was complicated by',
#  'pertinent consultations',
#  'rca',
#  'chronic back pain',
#  'integument',
#  'cardiac examination',
#  'mb',
#  'respiratory rate',
#  'identification',
#  'transfer orders',
#  'infectious disease provider',
#  'notation',
#  'medications upon discharge',
#  'visual field testing',
#  'the total bypass time',
#  '--- v-tach',
#  'history of present complaint',
#  'perinatal history',
#  'collected',
#  'treatments',
#  'memory',
#  'blood cultures',
#  'lymphatics',
#  'mental state',
#  'changes to discharge medications',
#  'irene field screening where',
#  'source',
#  'abdominal pain',
#  'contrast',
#  'net',
#  'labs at osh c cr',
#  'medications on transfer the stillman infirmary',
#  'cardiogram',
#  'lm',
#  'ct pelvis',
#  'discharge summary addendum',
#  'attention',
#  'v',
#  'consulting cardiac surgeon',
#  'at - home medications',
#  'left ventricle - diastolic dimension',
#  'aortic valve - peak velocity',
#  'general instructions',
#  'csf cytology',
#  'chemistries',
#  'kim phone',
#  'summary of hospital course by systems',
#  'ocuvite tablet sig',
#  'principal procedures',
#  'transfer condition',
#  'vagina',
#  'upright ap view of the chest',
#  'xi',
#  'cranial nerve exam',
#  'drains',
#  'discharge heart rhythm',
#  'products',
#  'other workup',
#  '- impression',
#  'specimen desc',
#  'leuprolide admit diagnosis',
#  'gastric biopsy',
#  'time spent with patient on day of discharge',
#  'genitalia',
#  'postoperative diagnosis',
#  'pertinent laboratories',
#  'read by',
#  'tc',
#  'hypothyroidism',
#  'hyperventilation',
#  'mitral valve - e wave',
#  'n',
#  'commun',
#  'progress',
#  'respiratory status',
#  'where',
#  'history of present illness and hospital course',
#  'condition at the time of discharge']

# %% [markdown]
# ---------------------------

# %% [markdown]
# ---------------------------

# %%
for f in filenames:
    reader = Reader(os.path.join(DATA_DIR, "train"), f)
    break

# %%
ms = re.findall('(\n[a-zA-Z -]+)( :\n)', reader.txt)
print(ms)
len(ms)
# for m in ms:
#     print(m.group(0))
# Out:
# [('\nDischarge Date', ' :\n'), ('\nDate of Birth', ' :\n'), ('\nSex', ' :\n'), ('\nAllergies', ' :\n'), ('\nChief Complaint', ' :\n'), ('\nMajor Surgical or Invasive Procedure', ' :\n'), ('\nHistory of Present Illness', ' :\n'), ('\nPast Medical History', ' :\n'), ('\nSocial History', ' :\n'), ('\nFamily History', ' :\n'), ('\nPhysical Exam', ' :\n'), ('\nBrief Hospital Course', ' :\n'), ('\nIndication', ' :\n'), ('\nMedications on Admission', ' :\n'), ('\nDischarge Medications', ' :\n'), ('\nDischarge Disposition', ' :\n'), ('\nDischarge Diagnosis', ' :\n'), ('\nDischarge Condition', ' :\n'), ('\nDischarge Instructions', ' :\n'), ('\nFollowup Instructions', ' :\n')]
# 20

# %%
# matches = re.finditer('[a-zA-Z ]+(( :\n)|( : ))', reader.txt)
matches = re.finditer('([a-zA-Z -]+)(( :\n)|( : ))', reader.txt)
for m in matches:
#     match = std_header(m.group(0))
    if not m:
        continue
    match = re.sub(':', '', m.group(0)).lower().strip()
    if match in ont_map: 
        continue
    b, e = m.span()
    print("=======================")
    print(match)
    print("-------------")
    print(reader.txt[max(b-10, 0):min(e+11, len(reader.txt))])
# Out:
# =======================
# sex
# -------------
# 981-03-17
# Sex :
# M
# Service :
# =======================
# service
# -------------
# 7
# Sex :
# M
# Service : MEDICINE
# Al
# =======================
# major surgical or invasive procedure
# -------------
#  vomiting
# Major Surgical or Invasive Procedure :
# 01-23 PORT
# =======================
# vitals
# -------------
# al Exam :
# Vitals : 97.4 , 164/
# =======================
# general
# -------------
#  , 97% 4L
# General : sleepy , ar
# =======================
# heent
# -------------
# ical exam
# HEENT : PERRL , lef
# =======================
# neck
# -------------
# P lesions
# Neck : Supple , no
# =======================
# cv
# -------------
#  , no JVD
# CV : RRR , nl S1
# =======================
# chest
# -------------
# CTAB post
# Chest : HD line in
# =======================
# abd
# -------------
#  erythema
# Abd : Soft , ND ,
# =======================
# ext
# -------------
# led scars
# Ext : no c/c/e ,
# =======================
# skin
# -------------
# od thrill
# Skin : no rashes
# B
# =======================
# brief hospital course
# -------------
# no rashes
# Brief Hospital Course :
# Pt admitted
# =======================
# hypertensive urgency
# -------------
# laints .
# # hypertensive urgency :
# Upon presen
# =======================
# bacteremia
# -------------
# egimen .
# # bacteremia :
# pt with 2/4
# =======================
# indication
# -------------
#  in OMR .
# Indication :
# diabetic ga
# =======================
# abdominal pain
# -------------
# t .
# # n/v/ abdominal pain : pt with mul
# =======================
# dmi
# -------------
# reglan .
# # DMI : Pt on slidi
# =======================
# esrd
# -------------
# dipine .
# # ESRD : etiology li
# =======================
# av fistula
# -------------
# es TID .
# # AV fistula : pt with h/o
# =======================
# dispo
# -------------
#  02-09 .
# # DISPO :
# pt discharg
# =======================
# medications on admission
# -------------
# service .
# Medications on Admission :
# Metoclopram
# =======================
# mg tablet sig
# -------------
# pramide 10 mg Tablet Sig : One ( 1 ) T
# =======================
# mg tablet sig
# -------------
# artrate 25 mg Tablet Sig : Three ( 3 )
# =======================
# mg capsule sig
# -------------
# cetate 667 mg Capsule Sig : Three ( 3 )
# =======================
# mg tablet sig
# -------------
# . Ativan 1 mg Tablet Sig : One ( 1 ) T
# =======================
# mg tablet sig
# -------------
# Dilaudid 4 mg Tablet Sig : One ( 1 ) T
# =======================
# hr patch weekly sig
# -------------
# .3 mg / 24 hr Patch Weekly Sig : One ( 1 ) P
# =======================
# mg tablet sig
# -------------
# nidine 0.2 mg Tablet Sig : One ( 1 ) T
# =======================
# mg tablet sig
# -------------
# Warfarin 1 mg Tablet Sig : 1.5 Tablets
# =======================
# mg tablet sustained release sig
# -------------
# edipine 30 mg Tablet Sustained Release Sig : One ( 1 ) T
# =======================
# sig
# -------------
# e ( E.C. ) Sig : One ( 1 ) T
# =======================
# mg tablet sig
# -------------
# isacodyl 5 mg Tablet Sig : One ( 1 ) T
# =======================
# ml piggyback sig
# -------------
#  1 g / 200 mL Piggyback Sig : One ( 1 ) I
# =======================
# mg tablet sig
# -------------
# Aspirin 81 mg Tablet Sig : One ( 1 ) T
# =======================
# ml solution sig
# -------------
# 100 unit / mL Solution Sig : USE AS DIRE
# =======================
# use as directed subcutaneous four times a day
# -------------
# ion Sig : USE AS DIRECTED Subcutaneous four times a day : please use
# =======================
# ml suspension sig
# -------------
# 100 unit / mL Suspension Sig : 2 UNITS Sub
# =======================
# discharge disposition
# -------------
# ls :* 2 *
# Discharge Disposition :
# Home
# Discha
# =======================
# discharge diagnosis
# -------------
# on :
# Home
# Discharge Diagnosis :
# primary :
# b
# =======================
# primary
# -------------
# agnosis :
# primary :
# bacteremia
# =======================
# discharge condition
# -------------
# stropathy
# Discharge Condition :
# stable .
# Di
# =======================
# completed by
# -------------
# MD 61-358
# Completed by : Elwood Edmo
# =======================
# signed electronically by
# -------------
# 31 @ 1141
# Signed electronically by : DR. Pamula
# =======================
# pamula pugh on
# -------------
# y by : DR. Pamula Pugh on : Russell 201
