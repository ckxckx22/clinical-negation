# %%
import os
import re
import json
import bisect

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DATA_DIR_RAW = '/Users/chenkx/Desktop/TBIC-not_synced/Negation/data/2010_relations_challenge'
DATA_DIR = r'/Users/chenkx/Box Sync/NLP group/2010 i2b2 challenge - rel'
MAP_DIR1 = "/Users/chenkx/Desktop/TBIC-not_synced/Negation/data/simple_header_map.json"
MAP_DIR2 = "/Users/chenkx/Desktop/TBIC-not_synced/Sectionizer/data/section_mapping/sectionTypeMapping.json"

# %%
with open(MAP_DIR1, 'r') as f:
    section_map1 = json.load(f)
with open(MAP_DIR2, 'r') as f:
    section_map2_tmp = json.load(f)
section_map2 = {}
# reformat section_map2 to lower case
for i in section_map2_tmp:
    section_map2[i.lower()] = section_map2_tmp[i].lower()
del section_map2_tmp

# %%
filenames = [i[:-4] for i in os.listdir(os.path.join(\
    DATA_DIR, "train", "txt")) \
     if i.endswith(".txt")]

# %%
file = filenames[0]

# %%
with open(os.path.join(DATA_DIR, 'train', 'ref', file+'.ann'), 'r') as f:
    ann = f.readlines()

# %%
def std_header(phrase):
    """
    standardize heading from regex matches.
    First, use simple rules to check if a phrase is a header. Rules:
        1. A header does not contain digits.
    Then, normalize headings by:
        1. converting to lower case
        2. trim white space.
    """    
    if re.search('(^mg )|(^ml )|(^g )', phrase):
        return None
    
    phrase = re.sub(" :$", "", phrase.strip().lower())
    if phrase in section_map1:
        phrase = section_map1[phrase]
    if phrase in section_map2:
        phrase = section_map2[phrase]
    
    if phrase == '':
        return None
    
    return phrase

# %%
class Reader:
    def __init__(self, path, fname):
        """
        :param path - Path to the folder of which subfolders include "txt" and "ref"
        """

        self._path = path
        self.fname = fname
        
        self.ann = {}
        self._ann_raw = []
        self.all_headings = []
        
        with open(os.path.join(self._path, "txt", self.fname+".txt"), 'r') as f:
            self.txt = f.read()
        
    def get_all_headings(self):
        matches = re.finditer('(\n[a-zA-Z -]+)(( :\n)|( : ))', reader.txt)
        for m in matches:
            match = std_header(m.group(0))
            if match:
                b, e = m.span()
                self.all_headings.append( (match, b, e) )
#         self.all_headings = [std_header(match) for i, match in enumerate([re.search('[a-zA-Z ]+(( :$)|( : ))', txt) for txt in self.txt.split('\n')])]
    
    def get_annotation(self):
        """
        {
            fname: {
                iterm_id: {
                    b: int begin_offset, 
                    e: int end_offset, 
                    t: str "type",
                    a: str "assertion", 
                    c: str "concept_raw_text", 
                    s: str "section"
                }
                length: int length of the note 
            }
        }

        """
        fname = self.fname
        with open(os.path.join(self._path, "ref", fname+".ann"), 'r') as f:
            ann_raw = f.read().split('\n')
            self._ann_raw = ann_raw
        
        annotations = {}
        for line in ann_raw:
            line = line.split('\t')
            if line[0].startswith('T'):
                annotations[line[0]] = {
                    'b': int(line[1].split()[1]),  
                    'e': int(line[1].split()[2]), 
                    't': line[1].split()[0], 
                    'a': None, 
                    'c': line[2], 
                    's': None
                }
        for line in ann_raw:
            line = line.split('\t')
            if line[0].startswith('A'):
                if line[1].split()[1] not in annotations:
                    print(f"Warning: {line[0]} ??")
                annotations[line[1].split()[1]]['a'] = line[1].split()[0]
                
        # remove annotations that don't have assertion informaiton 
        delete = []
        for i in annotations:
            if annotations[i]['a'] is None:
                delete.append(i)
        for i in delete:
            del annotations[i]
        
        annotations['length'] = len(self.txt)
        
        self.ann = {fname: annotations}

# %%
all_headings = []
for file in filenames:
    reader = Reader(os.path.join(DATA_DIR, "train"), file)
    reader.get_all_headings()
    all_headings.extend([i[0] for i in reader.all_headings])

# %%
len(all_headings)
# Out:
# 5966

# %%
# Save to disk 
# with open('all_headers.json', 'w') as f:
#     for i in sorted(list(set(all_headings))):
#         f.writelines(i + '::' + i + '\n')

# %%
len(set(all_headings))
# Out:
# 560

# %%
freq = {}
mapped = {}
for i in all_headings:
    if i in ont_map:
        if i not in mapped:
            mapped[i] = 0
        mapped[i] += 1
        continue
    if i not in freq:
        freq[i] = 0
    freq[i] +=1 
    
freq = [(i, "?", freq[i]) for i in freq]
mapped = [(i, ont_map[i], mapped[i]) for i in mapped]
# freq = sorted(list(freq.items()), key=lambda x:-x[1])
# mapped = sorted(list(mapped.items()), key=lambda x:-x[1])

# %%
to_write = [','.join([i[0], i[1], str(i[2])]) for i in sorted(freq+mapped, key=lambda x:-x[2])]

# %%
to_write[:5]
# Out:
# ['medications,Medications,248',
#  'd,?,181',
#  't,?,181',
#  'date,?,155',
#  'discharge date,Date/Time,155']

# %%
# with open('all_headings_2010.csv', 'w') as f:
#     f.writelines([ i + "\n" for i in to_write])

# %%
[i for i in set(all_headings) if i not in ont_map]
# for some of them manually map. 
# her discharge medications are as followsh, is a heading 
# sort by freq
# Out:
# ['daily status',
#  'abdo',
#  'follow up appointments scheduled',
#  'reason for this examination',
#  'rectal',
#  '- resumed coumadin as her home dose',
#  'primary care physician',
#  'care and recommendations at the time of discharge',
#  'urgency',
#  'capillary return',
#  'pulmonary',
#  'uterine incision type',
#  'meds on admission',
#  'hospital course and treatment',
#  'consultation',
#  'associated diagnosis',
#  'stable patient states complaint',
#  'o',
#  'her discharge medications are as follows',
#  'batch',
#  'admit diagnosis',
#  'lab work',
#  'imaging',
#  'his problems and management are as follows',
#  'labs and radiographic findings',
#  'blood pressure',
#  'follow up',
#  'other',
#  'general musculoskeletal',
#  'list of consultants',
#  'primary urgency',
#  'surgeries performed',
#  'past obstetric history',
#  'discharge status',
#  'comparisons',
#  'date',
#  'refills',
#  'principal procedure',
#  'conclusions',
#  'studies done during this hospitalization',
#  'maternal transfer',
#  'discharge orders',
#  'abdomen',
#  'objective',
#  'transferred to care of',
#  'final impression',
#  'laboratory data upon admission',
#  'treated with',
#  'adverse drug reactions',
#  'pre-cpb',
#  'followup plans',
#  'call the doctor or return to the thomas for',
#  'condition',
#  'median placenta',
#  'transferred to',
#  'evaluation date',
#  'author',
#  'allergy',
#  'ekg in john',
#  'follow up and instructions to patient',
#  'appreciate ortho input',
#  'pcp name',
#  'consults',
#  'discharge diet',
#  'hydration',
#  'diagnostic testing performed',
#  'other notable tests',
#  'all',
#  'operation',
#  'patient states complaint',
#  'consultants',
#  'exam',
#  'micro data',
#  'residents',
#  'ivc obstruction',
#  'underlying medical condition',
#  'past obstetrical history',
#  'cardiac risk factors',
#  'provisional admitting diagnosis',
#  'heart sounds',
#  'transfer date',
#  'personal history',
#  'pt',
#  'special procedures and operations',
#  'past gynecologic history',
#  'eye',
#  'registration date',
#  'discharge plans and followup',
#  'procedure during this hospitalization',
#  'instructions',
#  'general',
#  'ob-gyn history',
#  'spontaneous condition',
#  'patient statistics',
#  'admitting diagnoses',
#  'weight',
#  'impending spinal cord compression',
#  'consultants during this hospitalization',
#  'he remains in the intensive care unit suffers from the following problems',
#  'mcg inh daily diet',
#  'he was instructed to hold the following three medications that he took prior to admission',
#  'initial hospital course in the cardiac pavilion was as follows',
#  'audiology',
#  'pulm',
#  'breast feeding at discharge',
#  'condition at discharge',
#  'neurologic',
#  'ekg',
#  'brief medical history',
#  'significant laboratory data at time of admission',
#  'hypertensive urgency',
#  'past gyn history',
#  'general appearance',
#  'principal discharge diagnosis',
#  'vs',
#  'prenatal screens',
#  'signed electronically by',
#  'procedures performed',
#  'postpartum therapeutic procedures',
#  'chest x-ray upon admission',
#  'name',
#  'strength',
#  'epidural secondary anesthesia',
#  'standardized discharge instructions',
#  'cause of death',
#  'condition on transfer',
#  'alcohol',
#  'his condition is stable and he was discharged with the following medications',
#  'placenta',
#  'home medications',
#  'd',
#  'history',
#  'followup',
#  'the neurological examination',
#  'condition on discharge',
#  'renal failure',
#  '- check ekg',
#  'unit number',
#  'heent',
#  'psychosocial',
#  'secondary discharge diagnoses',
#  'cor',
#  'cesarean status',
#  'provider number',
#  'hospital course continued',
#  'date of death',
#  'date of expiration',
#  'vital signs on admission',
#  'power',
#  'technique',
#  'brief hospital course',
#  'previous override information',
#  'operations and procedures',
#  'ppx',
#  'primary pediatrician',
#  'vaginal delivery',
#  'medications at the time of discharge',
#  'transfer medications',
#  'serious interaction',
#  'assessment and plans',
#  'reflexes',
#  'course in hospital',
#  'estimated edc',
#  'operations and dates',
#  'critical care time',
#  'extremity exam',
#  'medication',
#  'svd operations and procedures',
#  'transferred',
#  'room',
#  'spontaneous episiotomy',
#  'postdischarge service',
#  'note',
#  'alert overridden',
#  'the patient was kept in the hospital and the following issues were addressed',
#  '- ct scan reading by radiologist',
#  'additional comments',
#  'mrn',
#  'cvs',
#  'fluid restriction',
#  'summary of hospitalization',
#  'skin exam',
#  'medications of discharge include',
#  'delivery date',
#  'physical examination on admission',
#  'micro',
#  'vitals',
#  'heart',
#  'impression on admission',
#  'include',
#  'chest',
#  'procedure performed',
#  'discharge follow-up',
#  'nodes',
#  'htn',
#  'electrocardiogram',
#  'cbc showed the following',
#  'studies',
#  'discharged diagnosis',
#  'intake',
#  'rate',
#  'bp site other',
#  'bipolar disorder',
#  'pupils',
#  'the patient presents with complaint of',
#  'current plan',
#  'murmurs',
#  'discharge summary name',
#  'complications of labor',
#  'impression and plan',
#  'gen',
#  'diagnostics',
#  'treatment rendered',
#  'approved',
#  'cmed',
#  'pt also counselled re',
#  'plantar responses',
#  'the results were as follows',
#  'back',
#  'electronically signed',
#  'transfer diagnoses',
#  'nutritional status',
#  'summary of hospital course',
#  'breasts',
#  'procedure note',
#  'physical assessment',
#  'heent exam',
#  'sex',
#  'impression and recommendations',
#  'associated procedures',
#  'physician followup',
#  'head and neck',
#  'tran',
#  'tobacco',
#  'plan for followup',
#  'recommendations',
#  'report',
#  'relevant laboratory data',
#  'her labs were the following',
#  'echo',
#  'service',
#  'special discharge instructions',
#  'non-contrast head ct',
#  'problems list',
#  'clinical history',
#  'ct of the pelvis without iv contrast',
#  'dd',
#  'resp',
#  'vent',
#  'r',
#  'adnexa',
#  'discharge patient on',
#  'follow-up care',
#  'care and recommendations',
#  'ekg upon admission',
#  'extremi-ties',
#  'postpartum care site',
#  'admission disposition',
#  'date of admission',
#  'discharge activity',
#  'current medications',
#  'sepsis risk factors',
#  'override notice',
#  'abg',
#  'discharge regimen',
#  'relevant imaging',
#  'initial newborn exam',
#  '- check stool occult',
#  'reason',
#  'manual condition',
#  'appearance',
#  'synagis rsv prophylaxis should be considered from october through april for infants who meet any of the following criteria',
#  'death summary',
#  'liver function tests',
#  'ecg',
#  'surgical procedure',
#  'brief resume of hospital course',
#  'cardiovascular exam',
#  'head',
#  'depression',
#  'delivery',
#  'diagnoses at time of death',
#  'pain',
#  'dictating for',
#  'principal diagnoses',
#  'contraindications for iv contrast',
#  'other procedures',
#  'monitor',
#  'c diff neg',
#  'hematology',
#  'epidural vaginal delivery',
#  'medications prior to admission',
#  'pulmonary angiogram',
#  'administer over',
#  'principal procedure performed while hospitalized',
#  'pertinent laboratory data',
#  'infuse rate',
#  'other postpartum therapies',
#  'postpartum disposition',
#  'subjective',
#  'associated diagnoses',
#  'cmed csru',
#  'admitting physician',
#  'indications for induction',
#  'physical examination on presentation',
#  'name of pediatrician',
#  'principal procedure or operation',
#  'state newborn screening status',
#  'rhythm',
#  'gastrointestinal',
#  'precordium',
#  'surgical procedures',
#  'cv',
#  'brief history of present illness',
#  'discharged',
#  'habits',
#  'bp',
#  'duration',
#  'lab values',
#  '- cycle troponins',
#  'significant labs upon discharge',
#  'principal diagnosis',
#  'digibsone instructions',
#  'gait',
#  'estimated disability and probable duration',
#  'dorsalis pedis pulse',
#  'pcc',
#  'she is now stable and is being discharged home on the following list of medications',
#  's',
#  'disability',
#  'transfer instructions',
#  'pertinent consults placed',
#  'course',
#  'brief hpi',
#  'dictator',
#  'immunizations recommended',
#  'description',
#  'incision type',
#  'discharge orders and instruction',
#  'neurology',
#  'other discharge instructions',
#  'attending physician',
#  'activity',
#  'postpartum rh immune globulin',
#  'pulse',
#  'thyroid',
#  'neuro',
#  'urinalysis',
#  'meds at transfer',
#  'pulmonary exam',
#  'pcp notified by md',
#  'secondary',
#  'oropharynx',
#  'follow-up appointments',
#  'provider',
#  'potentially serious interaction',
#  'doctors discharge orders and medications on discharge',
#  'pt refused to answere my questions',
#  'respirations',
#  'addendum hospital course',
#  'primary discharge diagnoses',
#  'osh imaging',
#  'notably you were discharged on',
#  'laboratory examination',
#  'ext',
#  'pertinent results',
#  'on exam',
#  'labs',
#  'cerebella',
#  'overdose',
#  't',
#  'physical examination',
#  'reason for override',
#  'brief clinical history',
#  'sensory',
#  'extr',
#  'follow-up plans',
#  'head and neck examination',
#  'etoh',
#  'post-bypass',
#  'history and reason for hospitalization',
#  'infectious disease',
#  'physical examination on admission to the cmed ccu',
#  'job id',
#  'cbc',
#  'ophthlologist',
#  'age',
#  'medications at the time of admission',
#  'ct of the abdomen without iv contrast',
#  'procedures',
#  'cxr',
#  'medical management',
#  'other diagnoses',
#  'principal procedures and tests',
#  'new results',
#  'bowel sounds',
#  'dict',
#  'her tube feeds orders are as follow',
#  'other medications ordered at the time of discharge',
#  'diagnoses upon discharge',
#  'summary',
#  'drug form',
#  'pmh',
#  'mental status',
#  'gi',
#  'primary discharge diagnosis',
#  'the following issues were addressed during this hospital admission',
#  'significant laboratories upon discharge',
#  'hypoxia and shortness of breath',
#  'physical examination upon admission',
#  'the cranial nerve exam',
#  'consultant',
#  'medicines on discharge',
#  'medications at discharge',
#  'pcp benefits assigned',
#  'skin',
#  'other pertinent secondary diagnoses',
#  'cardiac',
#  'social issues',
#  'benefits assigned',
#  '- check echo',
#  'by systems',
#  'ophthalmology',
#  'extremities',
#  'discharge condition',
#  'constitutional',
#  'msk',
#  'list of discharge medications',
#  'discontinued medications',
#  'laceration',
#  'cranial nerves',
#  'overall impression',
#  '- echo',
#  'md',
#  'problems and management are as follows',
#  'admission status',
#  'genitourinary',
#  'surface',
#  'principle diagnosis',
#  'list of medications',
#  'indications',
#  'cardiac exam',
#  'pertinent consults',
#  'significant laboratory data at the time of admission',
#  'principal tests and procedures',
#  'follow up service',
#  '- f',
#  'other laboratories that were notable',
#  'radiological studies at time of admission',
#  'procedure',
#  'attending of record',
#  'tr',
#  'allergy profile',
#  'admitted',
#  'temp',
#  'initial impression',
#  'veins',
#  'postdischarge testing',
#  'start',
#  'liver',
#  'substance use',
#  'the results from this exam are as follows',
#  'noncontrast cervical spine ct',
#  'transferred date',
#  'date of discharge',
#  'musculoskeletal',
#  'completed by',
#  'pulses',
#  'mouth',
#  'history and physical examination',
#  'neck',
#  'history and physical',
#  'fen',
#  'hypercalcemia',
#  'reason for hospitalization',
#  'red eye',
#  'called re',
#  'service of',
#  'potassium chloride policy',
#  'associated procedures or operations',
#  'dob',
#  'consultants during this admission',
#  'facility',
#  '- - consulted ophthlologist',
#  'respiratory',
#  'tenderness',
#  'escription document',
#  'diet',
#  'neuropsychiatric',
#  'discrete results only',
#  'history of present stay',
#  'history of the present illness and reason for hospitalization',
#  'consults obtained',
#  'significant problems',
#  'reviewed by',
#  'td',
#  'follow - up',
#  'certified nurse midwife',
#  'post-cpb',
#  'medications at time of discharge',
#  'labs on admission',
#  'ate of death',
#  'secondary diagnoses',
#  'other procedure',
#  'postoperative course',
#  'identification data',
#  'dicatated by',
#  'vvp instructions',
#  'the following issues were addressed during her hospital stay',
#  'hemodynamics',
#  'report status',
#  'entered by',
#  'rf',
#  'edc',
#  'home care',
#  'bs is not well controoled',
#  'radiologic studies',
#  'attend']

# %%
with open('../ClinicalSectionsOntology-v2.csv', 'r') as f:
    ont = f.read().split('\n')

# %%
ont_map = {}
for line in ont[2:]:
    keys = line.split(',')[5:]
    val = line.split(',')[0]
    key2 = line.split(',')[1]
    abbr = line.split(',')[2]
    ont_map[val.lower()] = val
    for k in keys:
        k = re.sub('"', '', k).strip()
        if k != '':
            ont_map[k.lower()] = val
    if key2 != '':
        ont_map[key2.lower()] = val
    if abbr != '':
        ont_map[abbr.lower()] = val

# %%
for f in filenames:
    reader = Reader(os.path.join(DATA_DIR, "train"), f)
    break

# %%
ms = re.findall('(\n[a-zA-Z -]+)( :\n)', reader.txt)
print(ms)
len(ms)
# for m in ms:
#     print(m.group(0))
# Out:
# [('\nDischarge Date', ' :\n'), ('\nDate of Birth', ' :\n'), ('\nSex', ' :\n'), ('\nAllergies', ' :\n'), ('\nChief Complaint', ' :\n'), ('\nMajor Surgical or Invasive Procedure', ' :\n'), ('\nHistory of Present Illness', ' :\n'), ('\nPast Medical History', ' :\n'), ('\nSocial History', ' :\n'), ('\nFamily History', ' :\n'), ('\nPhysical Exam', ' :\n'), ('\nBrief Hospital Course', ' :\n'), ('\nIndication', ' :\n'), ('\nMedications on Admission', ' :\n'), ('\nDischarge Medications', ' :\n'), ('\nDischarge Disposition', ' :\n'), ('\nDischarge Diagnosis', ' :\n'), ('\nDischarge Condition', ' :\n'), ('\nDischarge Instructions', ' :\n'), ('\nFollowup Instructions', ' :\n')]
# 20

# %%
# matches = re.finditer('[a-zA-Z ]+(( :\n)|( : ))', reader.txt)
matches = re.finditer('([a-zA-Z -]+)(( :\n)|( : ))', reader.txt)
for m in matches:
#     match = std_header(m.group(0))
    if not m:
        continue
    match = re.sub(':', '', m.group(0)).lower().strip()
    if match in ont_map: 
        continue
    b, e = m.span()
    print("=======================")
    print(match)
    print("-------------")
    print(reader.txt[max(b-10, 0):min(e+11, len(reader.txt))])
# Out:
# =======================
# sex
# -------------
# 981-03-17
# Sex :
# M
# Service :
# =======================
# service
# -------------
# 7
# Sex :
# M
# Service : MEDICINE
# Al
# =======================
# major surgical or invasive procedure
# -------------
#  vomiting
# Major Surgical or Invasive Procedure :
# 01-23 PORT
# =======================
# vitals
# -------------
# al Exam :
# Vitals : 97.4 , 164/
# =======================
# general
# -------------
#  , 97% 4L
# General : sleepy , ar
# =======================
# heent
# -------------
# ical exam
# HEENT : PERRL , lef
# =======================
# neck
# -------------
# P lesions
# Neck : Supple , no
# =======================
# cv
# -------------
#  , no JVD
# CV : RRR , nl S1
# =======================
# chest
# -------------
# CTAB post
# Chest : HD line in
# =======================
# abd
# -------------
#  erythema
# Abd : Soft , ND ,
# =======================
# ext
# -------------
# led scars
# Ext : no c/c/e ,
# =======================
# skin
# -------------
# od thrill
# Skin : no rashes
# B
# =======================
# brief hospital course
# -------------
# no rashes
# Brief Hospital Course :
# Pt admitted
# =======================
# hypertensive urgency
# -------------
# laints .
# # hypertensive urgency :
# Upon presen
# =======================
# bacteremia
# -------------
# egimen .
# # bacteremia :
# pt with 2/4
# =======================
# indication
# -------------
#  in OMR .
# Indication :
# diabetic ga
# =======================
# abdominal pain
# -------------
# t .
# # n/v/ abdominal pain : pt with mul
# =======================
# dmi
# -------------
# reglan .
# # DMI : Pt on slidi
# =======================
# esrd
# -------------
# dipine .
# # ESRD : etiology li
# =======================
# av fistula
# -------------
# es TID .
# # AV fistula : pt with h/o
# =======================
# dispo
# -------------
#  02-09 .
# # DISPO :
# pt discharg
# =======================
# medications on admission
# -------------
# service .
# Medications on Admission :
# Metoclopram
# =======================
# mg tablet sig
# -------------
# pramide 10 mg Tablet Sig : One ( 1 ) T
# =======================
# mg tablet sig
# -------------
# artrate 25 mg Tablet Sig : Three ( 3 )
# =======================
# mg capsule sig
# -------------
# cetate 667 mg Capsule Sig : Three ( 3 )
# =======================
# mg tablet sig
# -------------
# . Ativan 1 mg Tablet Sig : One ( 1 ) T
# =======================
# mg tablet sig
# -------------
# Dilaudid 4 mg Tablet Sig : One ( 1 ) T
# =======================
# hr patch weekly sig
# -------------
# .3 mg / 24 hr Patch Weekly Sig : One ( 1 ) P
# =======================
# mg tablet sig
# -------------
# nidine 0.2 mg Tablet Sig : One ( 1 ) T
# =======================
# mg tablet sig
# -------------
# Warfarin 1 mg Tablet Sig : 1.5 Tablets
# =======================
# mg tablet sustained release sig
# -------------
# edipine 30 mg Tablet Sustained Release Sig : One ( 1 ) T
# =======================
# sig
# -------------
# e ( E.C. ) Sig : One ( 1 ) T
# =======================
# mg tablet sig
# -------------
# isacodyl 5 mg Tablet Sig : One ( 1 ) T
# =======================
# ml piggyback sig
# -------------
#  1 g / 200 mL Piggyback Sig : One ( 1 ) I
# =======================
# mg tablet sig
# -------------
# Aspirin 81 mg Tablet Sig : One ( 1 ) T
# =======================
# ml solution sig
# -------------
# 100 unit / mL Solution Sig : USE AS DIRE
# =======================
# use as directed subcutaneous four times a day
# -------------
# ion Sig : USE AS DIRECTED Subcutaneous four times a day : please use
# =======================
# ml suspension sig
# -------------
# 100 unit / mL Suspension Sig : 2 UNITS Sub
# =======================
# discharge disposition
# -------------
# ls :* 2 *
# Discharge Disposition :
# Home
# Discha
# =======================
# discharge diagnosis
# -------------
# on :
# Home
# Discharge Diagnosis :
# primary :
# b
# =======================
# primary
# -------------
# agnosis :
# primary :
# bacteremia
# =======================
# discharge condition
# -------------
# stropathy
# Discharge Condition :
# stable .
# Di
# =======================
# completed by
# -------------
# MD 61-358
# Completed by : Elwood Edmo
# =======================
# signed electronically by
# -------------
# 31 @ 1141
# Signed electronically by : DR. Pamula
# =======================
# pamula pugh on
# -------------
# y by : DR. Pamula Pugh on : Russell 201
